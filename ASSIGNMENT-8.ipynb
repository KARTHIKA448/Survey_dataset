# %%
import pandas as pd

# %%
survey=pd.read_csv("survey_results_public.csv",index_col="Respondent")
survey
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
data=survey.copy()
data
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
schema=pd.read_csv("survey_results_schema.csv",index_col="Column")
schema.sort_index()
# Out:
#                                                     QuestionText
# Column
# Age            What is your age (in years)? If you prefer not...
# Age1stCode     At what age did you write your first line of c...
# BetterLife     Do you think people born today will have a bet...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BlockchainOrg  How is your organization thinking about or imp...
# ...                                                          ...
# WorkPlan                 How structured or planned is your work?
# WorkRemote                       How often do you work remotely?
# WorkWeekHrs     On average, how many hours per week do you work?
# YearsCode      Including any education, how many years have y...
# YearsCodePro   How many years have you coded professionally (...
#
# [85 rows x 1 columns]

# %%
survey.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %% [markdown]
# ### q1.Experiment with argmax and percentage of python users(try different thresholds)

# %% [markdown]
# ### q2.Value counts of Gender wise by Country

# %%
country_group=survey.groupby("Country")

# %%
country_group["Gender"].value_counts()
# Out:
# Country      Gender
# Afghanistan  Man                                                            26
#              Woman                                                           2
#              Non-binary, genderqueer, or gender non-conforming               1
#              Woman;Man;Non-binary, genderqueer, or gender non-conforming     1
# Albania      Man                                                            70
#                                                                             ..
# Yemen        Woman;Man                                                       1
# Zambia       Man                                                            11
#              Woman                                                           1
# Zimbabwe     Man                                                            37
#              Woman                                                           2
# Name: Gender, Length: 539, dtype: int64

# %% [markdown]
# ### q3.Gender wise Python Users in each country

# %%
gender_group=survey.groupby("Gender")

# %%
survey(gender_group["LanguageWorkedWith"].apply(lambda x:x.str.contains("Python")))
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10148\842668323.py:1: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   survey(gender_group["LanguageWorkedWith"].apply(lambda x:x.str.contains("Python")))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 survey(gender_group["LanguageWorkedWith"].apply(lambda x:x.str.contains("Python")))
#
# TypeError: 'DataFrame' object is not callable

# %%
gender_g

# %%
country_group['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 country_group['LanguageWorkedWith'].str.contains('Python').sum()
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:987, in GroupBy.__getattr__(self, attr)
#     984 if attr in self.obj:
#     985     return self[attr]
# --> 987 raise AttributeError(
#     988     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     989 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %% [markdown]
# ### q3.Groupby EdLevel, Salary Median

# %%
ed_group=survey.groupby("EdLevel")

# %%
ed_group["ConvertedComp"].median()
# Out:
# EdLevel
# Associate degree                                                                      56092.5
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              60000.0
# I never completed any formal education                                                53562.0
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                           57744.0
# Other doctoral degree (Ph.D, Ed.D., etc.)                                             81960.0
# Primary/elementary school                                                             34368.0
# Professional degree (JD, MD, etc.)                                                    32998.0
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    37128.0
# Some college/university study without earning a degree                                52476.0
# Name: ConvertedComp, dtype: float64

# %% [markdown]
# ### ? Years of experience grouping> Salary in terms of Years of Experience(median)

# %%
exprn_group=survey.groupby("YearsCode")

# %%
exprn_group["ConvertedComp"].median()
# Out:
# YearsCode
# 1                      23172.0
# 10                     51034.0
# 11                     53460.0
# 12                     57744.0
# 13                     58391.5
# 14                     62903.5
# 15                     65544.5
# 16                     68745.0
# 17                     72182.0
# 18                     77888.0
# 19                     81092.5
# 2                      23088.0
# 20                     83640.0
# 21                     89158.0
# 22                     91660.0
# 23                     91593.0
# 24                     90439.5
# 25                     91660.0
# 26                     91593.0
# 27                     93000.0
# 28                    100000.0
# 29                     86869.5
# 3                      27852.0
# 30                     98075.0
# 31                     91868.0
# 32                     91660.0
# 33                     98352.0
# 34                     98520.0
# 35                    106874.0
# ...

# %% [markdown]
# ### ? Years of experience grouping> Count of Gender

# %%
schema.loc["YearsCode","QuestionText"]
# Out:
# 'Including any education, how many years have you been coding?'

# %%
exprn_group=survey.groupby("YearsCode")

# %%
exprn_group["Gender"].value_counts()
# Out:
# YearsCode           Gender
# 1                   Man                                                            1438
#                     Woman                                                           242
#                     Non-binary, genderqueer, or gender non-conforming                13
#                     Woman;Man                                                         8
#                     Man;Non-binary, genderqueer, or gender non-conforming             6
#                                                                                    ...
# Less than 1 year    Woman;Man;Non-binary, genderqueer, or gender non-conforming       2
# More than 50 years  Man                                                             104
#                     Woman                                                             4
#                     Woman;Man;Non-binary, genderqueer, or gender non-conforming       3
# ...

# %% [markdown]
# ### ? Country wise grouping>> Retreieve how much blockchain tech is famous/implemented in organizations

# %%
survey["BlockchainOrg"].unique()
# Out:
# array([nan, 'Not at all', 'Implementing cryptocurrency-based products',
#        'Non-currency applications of blockchain',
#        'Implementing our own cryptocurrency',
#        'Accepting Bitcoin or other coins and tokens as payments'],
#       dtype=object)

# %%
country_group=survey.groupby("Country")

# %%
country_group["BlockchainOrg"].value_counts()
# Out:
# Country      BlockchainOrg
# Afghanistan  Not at all                                                  6
#              Accepting Bitcoin or other coins and tokens as payments     3
#              Implementing cryptocurrency-based products                  1
#              Implementing our own cryptocurrency                         1
# Albania      Not at all                                                 35
#                                                                         ..
# Yemen        Not at all                                                  2
# Zambia       Not at all                                                  2
# Zimbabwe     Not at all                                                 11
#              Implementing cryptocurrency-based products                  1
#              Non-currency applications of blockchain                     1
# Name: BlockchainOrg, Length: 573, dtype: int64

# %%
country_group["BlockchainOrg"].str.contains("Implementing cryptocurrency-based products" | "Implementing our own cryptocurrency").value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 country_group["BlockchainOrg"].str.contains("Implementing cryptocurrency-based products" | "Implementing our own cryptocurrency").value_counts()
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:987, in GroupBy.__getattr__(self, attr)
#     984 if attr in self.obj:
#     985     return self[attr]
# --> 987 raise AttributeError(
#     988     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     989 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
BlockchainIs

# %%
survey["BlockchainIs"].unique()
# Out:
# array([nan,
#        'Useful across many domains and could change many aspects of our lives',
#        'Useful for decentralized currency (i.e., Bitcoin)',
#        'An irresponsible use of resources',
#        'Useful for immutable record keeping outside of currency',
#        'A passing fad'], dtype=object)

# %%
country_group["BlockchainIs"].value_counts()
# Out:
# Country      BlockchainIs
# Afghanistan  Useful across many domains and could change many aspects of our lives     6
#              A passing fad                                                             5
#              Useful for immutable record keeping outside of currency                   5
#              An irresponsible use of resources                                         2
#              Useful for decentralized currency (i.e., Bitcoin)                         1
#                                                                                       ..
# Zambia       Useful for immutable record keeping outside of currency                   1
# Zimbabwe     Useful across many domains and could change many aspects of our lives    11
#              Useful for immutable record keeping outside of currency                   8
#              Useful for decentralized currency (i.e., Bitcoin)                         7
# ...
