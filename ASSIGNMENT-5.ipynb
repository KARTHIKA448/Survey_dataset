# %%
import pandas as pd

# %%
survey=pd.read_csv("survey_results_public.csv",index_col=["Respondent"])
survey
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
schema=pd.read_csv("survey_results_schema.csv",index_col="Column")
schema
# Out:
#                                                    QuestionText
# Column
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %%
schema.sort_index()
# Out:
#                                                     QuestionText
# Column
# Age            What is your age (in years)? If you prefer not...
# Age1stCode     At what age did you write your first line of c...
# BetterLife     Do you think people born today will have a bet...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BlockchainOrg  How is your organization thinking about or imp...
# ...                                                          ...
# WorkPlan                 How structured or planned is your work?
# WorkRemote                       How often do you work remotely?
# WorkWeekHrs     On average, how many hours per week do you work?
# YearsCode      Including any education, how many years have y...
# YearsCodePro   How many years have you coded professionally (...
#
# [85 rows x 1 columns]

# %%
survey_data=survey.copy()
survey_data
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
survey.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %% [markdown]
# ### Q1 - remove rows from 1000 to 1050

# %%
survey.drop(survey.loc[1000:1050].index)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
survey.drop(survey.loc[1000:1050].index).loc[998:1055]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 998         I am a student who is learning to code      Yes
# 999                 I am a developer by profession      Yes
# 1051                I am a developer by profession      Yes
# 1052                I am a developer by profession      Yes
# 1053        I am a student who is learning to code      Yes
# 1054                I am a developer by profession      Yes
# 1055                I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 998                                   Less than once per year
# 999                                   Less than once per year
# 1051        Less than once a month but more than once per ...
# 1052                                                    Never
# 1053                                  Less than once per year
# 1054        Less than once a month but more than once per ...
# ...

# %% [markdown]
# ###### or

# %%
survey.drop(survey.loc[1000:1050].index,axis=0).loc[998:1055]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 998         I am a student who is learning to code      Yes
# 999                 I am a developer by profession      Yes
# 1051                I am a developer by profession      Yes
# 1052                I am a developer by profession      Yes
# 1053        I am a student who is learning to code      Yes
# 1054                I am a developer by profession      Yes
# 1055                I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 998                                   Less than once per year
# 999                                   Less than once per year
# 1051        Less than once a month but more than once per ...
# 1052                                                    Never
# 1053                                  Less than once per year
# 1054        Less than once a month but more than once per ...
# ...

# %% [markdown]
# ### Q2- Remove rows where Age is missing

# %%
survey["Age"].value_counts()
# Out:
# 25.0    4669
# 24.0    4428
# 27.0    4418
# 26.0    4397
# 28.0    4387
#         ...
# 24.8       1
# 90.0       1
# 61.3       1
# 4.0        1
# 87.0       1
# Name: Age, Length: 126, dtype: int64

# %%
survey["Age"].unique()
# Out:
# array([14. , 19. , 28. , 22. , 30. , 42. , 24. , 23. ,  nan, 21. , 31. ,
#        20. , 26. , 29. , 38. , 47. , 34. , 32. , 25. , 17. , 35. , 27. ,
#        44. , 43. , 62. , 37. , 45. , 18. , 33. , 36. , 16. , 39. , 64. ,
#        41. , 54. , 49. , 40. , 56. , 12. , 58. , 46. , 59. , 51. , 48. ,
#        57. , 52. , 50. , 23.9, 55. , 15. , 67. , 13. ,  1. , 53. , 69. ,
#        65. , 17.5, 63. , 61. , 68. , 73. , 70. , 60. , 16.5, 46.5, 11. ,
#        71. ,  3. , 97. , 29.5, 77. , 74. , 26.5, 26.3, 24.5, 78. , 72. ,
#        66. , 76. , 10. , 75. , 99. , 83. , 79. , 36.8, 14.1, 13.5, 19.5,
#        98. , 43.5, 22.5, 31.5, 21.5, 28.5, 33.6,  2. , 38.5, 30.8, 24.8,
#        90. , 61.3, 81. ,  4. , 17.3, 19.9, 80. , 85. , 88. , 23.5, 16.9,
#        20.9, 91. , 98.9, 57.9,  9. , 94. , 95. , 37.5, 14.5,  5. , 82. ,
#        84. , 37.3, 33.5, 53.8, 31.4, 87. ])

# %%
survey["Age"].isnull().sum()
# Out:
# 9673

# %%
data=survey.drop(survey.loc[survey["Age"].isnull()==True,"Age"].index)
data
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 87352                                                     NaN      Yes
# 87386                                                     NaN      Yes
# 87739                                                     NaN      Yes
# 88212                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
data=survey.drop(survey.loc[survey["Age"].isnull()==True,"Age"].index,axis=0)

# %%
data["Age"].isnull().sum()
# Out:
# 0

# %%
data["Age"].unique()
# Out:
# array([14. , 19. , 28. , 22. , 30. , 42. , 24. , 23. , 21. , 31. , 20. ,
#        26. , 29. , 38. , 47. , 34. , 32. , 25. , 17. , 35. , 27. , 44. ,
#        43. , 62. , 37. , 45. , 18. , 33. , 36. , 16. , 39. , 64. , 41. ,
#        54. , 49. , 40. , 56. , 12. , 58. , 46. , 59. , 51. , 48. , 57. ,
#        52. , 50. , 23.9, 55. , 15. , 67. , 13. ,  1. , 53. , 69. , 65. ,
#        17.5, 63. , 61. , 68. , 73. , 70. , 60. , 16.5, 46.5, 11. , 71. ,
#         3. , 97. , 29.5, 77. , 74. , 26.5, 26.3, 24.5, 78. , 72. , 66. ,
#        76. , 10. , 75. , 99. , 83. , 79. , 36.8, 14.1, 13.5, 19.5, 98. ,
#        43.5, 22.5, 31.5, 21.5, 28.5, 33.6,  2. , 38.5, 30.8, 24.8, 90. ,
#        61.3, 81. ,  4. , 17.3, 19.9, 80. , 85. , 88. , 23.5, 16.9, 20.9,
#        91. , 98.9, 57.9,  9. , 94. , 95. , 37.5, 14.5,  5. , 82. , 84. ,
#        37.3, 33.5, 53.8, 31.4, 87. ])

# %% [markdown]
# ### Q3 - Remove features about the personal info of developer

# %%
schema.loc["Ethnicity","QuestionText"]
# Out:
# 'Which of the following do you identify as? Please check all that apply. If you prefer not to answer, you may leave this question blank.'

# %%
schema.loc["BetterLife","QuestionText"]
# Out:
# 'Do you think people born today will have a better life than their parents?'

# %%
schema.loc["Dependents","QuestionText"]
# Out:
# 'Do you have any dependents (e.g., children, elders, or others) that you care for?'

# %%
personal_info=["Age","Gender","Trans","Sexuality","Dependents","BetterLife"]

# %%
survey.drop(personal_info,axis=1)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
(survey.drop(personal_info,axis=1)).columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %% [markdown]
# ### Q4-Remove developers who are 'Neither satisfied nor dissatisfied'

# %%
survey["JobSat"].unique()
# Out:
# array([nan, 'Slightly satisfied', 'Slightly dissatisfied',
#        'Neither satisfied nor dissatisfied', 'Very satisfied',
#        'Very dissatisfied'], dtype=object)

# %%
survey.drop(survey.loc[survey["JobSat"]=="Neither satisfied nor dissatisfied","JobSat"].index,axis=0)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
jobys=survey.drop(survey.loc[survey["JobSat"]=="Neither satisfied nor dissatisfied","JobSat"].index,axis=0)
jobys
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
jobys["JobSat"].unique()
# Out:
# array([nan, 'Slightly satisfied', 'Slightly dissatisfied',
#        'Very satisfied', 'Very dissatisfied'], dtype=object)

# %% [markdown]
# ### Q5-Filter developers who are looking forward to work with MySQL data base next year

# %%
schema.loc["DatabaseDesireNextYear","QuestionText"]
# Out:
# 'Which of the following database environments have you done extensive development work in over the past year, and which do you want to work in over the next year?   (If you both worked with the database and want to continue to do so, please check both boxes in that row.)'

# %%
survey["DatabaseDesireNextYear"]
# Out:
# Respondent
# 1                                                    MySQL
# 2                                                    MySQL
# 3                                               PostgreSQL
# 4                                             MySQL;SQLite
# 5        Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
#                                ...
# 88377                                Firebase;MySQL;SQLite
# 88601                                                  NaN
# 88802                                                  NaN
# 88816                                                  NaN
# 88863                          MariaDB;MySQL;Oracle;SQLite
# Name: DatabaseDesireNextYear, Length: 88883, dtype: object

# %%
mysql=survey["DatabaseDesireNextYear"].str.contains("MySQL",na=False)
survey.loc[mysql,"DatabaseDesireNextYear"]
# Out:
# Respondent
# 1                                                    MySQL
# 2                                                    MySQL
# 4                                             MySQL;SQLite
# 5        Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
# 8        Cassandra;DynamoDB;Elasticsearch;Firebase;Mong...
#                                ...
# 85955             Microsoft SQL Server;MySQL;Oracle;SQLite
# 86806    Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 87739                                                MySQL
# 88377                                Firebase;MySQL;SQLite
# 88863                          MariaDB;MySQL;Oracle;SQLite
# Name: DatabaseDesireNextYear, Length: 25750, dtype: object

# %%
survey.loc[mysql,"DatabaseDesireNextYear"].value_counts()
# Out:
# MySQL                                                                              3184
# MongoDB;MySQL                                                                       917
# MySQL;SQLite                                                                        874
# Microsoft SQL Server;MySQL                                                          827
# MySQL;PostgreSQL                                                                    720
#                                                                                    ...
# Cassandra;Elasticsearch;Microsoft SQL Server;MySQL;Redis                              1
# Elasticsearch;MongoDB;Microsoft SQL Server;MySQL;SQLite;Other(s):                     1
# DynamoDB;Elasticsearch;MariaDB;MySQL;PostgreSQL;Redis;Other(s):                       1
# Cassandra;DynamoDB;Elasticsearch;MongoDB;MySQL;PostgreSQL;SQLite                      1
# DynamoDB;MariaDB;MongoDB;Microsoft SQL Server;MySQL;PostgreSQL;SQLite;Other(s):       1
# ...

# %%
(survey.loc[mysql,"DatabaseDesireNextYear"]).shape
# Out:
# (25750,)

# %% [markdown]
# ### Q6 - filter developers who got hired less than a year ago and let me know their age and where are they actually from?

# %%
schema.loc["LastHireDate","QuestionText"]
# Out:
# 'When was the last time that you took a job with a new employer?'

# %%
survey["LastHireDate"].unique()
# Out:
# array([nan, "I've never had a job", '1-2 years ago',
#        'Less than a year ago',
#        'NA - I am an independent contractor or self employed',
#        '3-4 years ago', 'More than 4 years ago'], dtype=object)

# %%
survey.loc[(survey["LastHireDate"]=="Less than a year ago"),["Age","Country","LastHireDate"]]
# Out:
#              Age        Country          LastHireDate
# Respondent
# 4           22.0  United States  Less than a year ago
# 5           30.0        Ukraine  Less than a year ago
# 9           23.0    New Zealand  Less than a year ago
# 12          21.0         Canada  Less than a year ago
# 17          29.0      Australia  Less than a year ago
# ...          ...            ...                   ...
# 88871       22.0         Poland  Less than a year ago
# 88874       26.0  United States  Less than a year ago
# 88878       26.0  United States  Less than a year ago
# 88880        NaN  United States  Less than a year ago
# 88882        NaN    Netherlands  Less than a year ago
#
# [25844 rows x 3 columns]

# %% [markdown]
# ###### or

# %%
less_than_a_year=survey["LastHireDate"].str.contains("Less than a year ago",na=False)
survey.loc[less_than_a_year,"LastHireDate"]
# Out:
# Respondent
# 4        Less than a year ago
# 5        Less than a year ago
# 9        Less than a year ago
# 12       Less than a year ago
# 17       Less than a year ago
#                  ...
# 88871    Less than a year ago
# 88874    Less than a year ago
# 88878    Less than a year ago
# 88880    Less than a year ago
# 88882    Less than a year ago
# Name: LastHireDate, Length: 25844, dtype: object
