# %%
import pandas as pd

# %%
survey_data=pd.read_csv("survey_results_public.csv")
survey_data
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
survey=survey_data.set_index("Respondent")
survey
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
schema_data=pd.read_csv("survey_results_schema.csv")
schema_data
# Out:
#           Column                                       QuestionText
# 0     Respondent  Randomized respondent ID number (not in order ...
# 1     MainBranch  Which of the following options best describes ...
# 2       Hobbyist                            Do you code as a hobby?
# 3    OpenSourcer        How often do you contribute to open source?
# 4     OpenSource  How do you feel about the quality of open sour...
# ..           ...                                                ...
# 80     Sexuality  Which of the following do you currently identi...
# 81     Ethnicity  Which of the following do you identify as? Ple...
# 82    Dependents  Do you have any dependents (e.g., children, el...
# 83  SurveyLength  How do you feel about the length of the survey...
# 84    SurveyEase  How easy or difficult was this survey to compl...
#
# [85 rows x 2 columns]

# %%
schema=schema_data.set_index("Column")
schema
# Out:
#                                                    QuestionText
# Column
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %%
survey.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
schema.loc["ConvertedComp","QuestionText"]
# Out:
# 'Salary converted to annual USD salaries using the exchange rate on 2019-02-01, assuming 12 working months and 50 working weeks.'

# %%
survey["Gender"].unique()
# Out:
# array(['Man', nan, 'Woman',
#        'Non-binary, genderqueer, or gender non-conforming',
#        'Woman;Non-binary, genderqueer, or gender non-conforming',
#        'Woman;Man;Non-binary, genderqueer, or gender non-conforming',
#        'Woman;Man',
#        'Man;Non-binary, genderqueer, or gender non-conforming'],
#       dtype=object)

# %% [markdown]
# ## 1. age 20-30 ,salary-15L ,Gender -Female

# %%
-age 20to 30
-sal 15L
-gender female

# %%
agesalgen=(survey["Age"].between(20,30)) & (survey["ConvertedComp"]==1500000) & (survey["Gender"]=="Woman")

# %%
survey.loc[agesalgen,["Age","Gender","ConvertedComp"]]
# Out:
# Empty DataFrame
# Columns: [Age, Gender, ConvertedComp]
# Index: []

# %%
agesalgen=(survey["Age"].between(20,30)) & (survey["ConvertedComp"]==1500000)
survey.loc[agesalgen,["Age","Gender","ConvertedComp"]]
# Out:
#              Age Gender  ConvertedComp
# Respondent
# 13615       27.0    Man      1500000.0
# 33237       25.0    Man      1500000.0
# 35274       28.0    Man      1500000.0
# 44313       28.0    Man      1500000.0
# 45282       26.0    Man      1500000.0
# 75580       27.0    Man      1500000.0

# %% [markdown]
# ### 2.Developers who gets more than 15L, and are they satisfied in their working environment

# %%
-earns > 15
-jobsatisfaction

# %%
schema.loc["JobSat","QuestionText"]
# Out:
# 'How satisfied are you with your current job? (If you work multiple jobs, answer for the one you spend the most hours on.)'

# %%
survey["JobSat"].unique()
# Out:
# array([nan, 'Slightly satisfied', 'Slightly dissatisfied',
#        'Neither satisfied nor dissatisfied', 'Very satisfied',
#        'Very dissatisfied'], dtype=object)

# %%
survey.loc[survey["ConvertedComp"]>1500000 ,[ "JobSat"]]
# Out:
#                                         JobSat
# Respondent
# 58                              Very satisfied
# 102                         Slightly satisfied
# 166                         Slightly satisfied
# 436                         Slightly satisfied
# 452                             Very satisfied
# ...                                        ...
# 88712                    Slightly dissatisfied
# 88815       Neither satisfied nor dissatisfied
# 88818                       Slightly satisfied
# 88874                           Very satisfied
# 88877                           Very satisfied
#
# [839 rows x 1 columns]

# %%
survey.loc[survey["ConvertedComp"]>1500000 ,[ "JobSat"]].value_counts()
# Out:
# JobSat
# Very satisfied                        335
# Slightly satisfied                    279
# Slightly dissatisfied                  98
# Neither satisfied nor dissatisfied     72
# Very dissatisfied                      55
# dtype: int64

# %%
survey.loc[survey["ConvertedComp"]>1500000 ,[ "JobSat","ConvertedComp"]]
# Out:
#                                         JobSat  ConvertedComp
# Respondent
# 58                              Very satisfied      2000000.0
# 102                         Slightly satisfied      2000000.0
# 166                         Slightly satisfied      2000000.0
# 436                         Slightly satisfied      2000000.0
# 452                             Very satisfied      2000000.0
# ...                                        ...            ...
# 88712                    Slightly dissatisfied      2000000.0
# 88815       Neither satisfied nor dissatisfied      2000000.0
# 88818                       Slightly satisfied      2000000.0
# 88874                           Very satisfied      2000000.0
# 88877                           Very satisfied      2000000.0
#
# [839 rows x 2 columns]

# %%
survey["Country"].unique()
# Out:
# array(['United Kingdom', 'Bosnia and Herzegovina', 'Thailand',
#        'United States', 'Ukraine', 'Canada', 'India', 'New Zealand',
#        'Antigua and Barbuda', 'Germany', 'Australia',
#        'Russian Federation', 'Brazil', 'Lithuania', 'Israel',
#        'South Africa', 'Colombia', 'Turkey', 'Switzerland', 'Argentina',
#        'Sri Lanka', 'Czech Republic', 'Denmark', 'Malaysia', 'Bangladesh',
#        'Spain', 'Serbia', 'Poland', 'Sweden', 'China', 'France',
#        'Netherlands', 'Italy', 'Philippines', 'Ireland', 'Pakistan',
#        'Azerbaijan', 'Austria', 'Estonia', 'Croatia', 'South Korea',
#        'Greece', 'Japan', 'Romania', 'Finland', 'Bulgaria', 'Viet Nam',
#        'Slovenia', 'Iran', 'Belarus', 'Hungary', 'Latvia',
#        'Hong Kong (S.A.R.)', 'United Arab Emirates', 'Portugal',
#        'Nigeria', 'Norway', 'Nicaragua', 'Zimbabwe', 'Egypt', 'Mexico',
#        'Dominican Republic', 'Guatemala', 'Chile', 'Ecuador', 'Ghana',
# ...

# %% [markdown]
# ### 3.Does SAARC countries exist in the dataframe

# %%
SAARC_COUNTRIES=("Afghanistan","Bangladesh","Bhutan","India","Maldives","Nepal","Pakistan","Sri Lanka")
SAARC_COUNTRIES
# Out:
# ('Afghanistan',
#  'Bangladesh',
#  'Bhutan',
#  'India',
#  'Maldives',
#  'Nepal',
#  'Pakistan',
#  'Sri Lanka')

# %%
survey.loc[survey["Country"].isin(SAARC_COUNTRIES)]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 34          I am a student who is learning to code      Yes
# 42                  I am a developer by profession      Yes
# ...                                            ...      ...
# 81624                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
# 88182                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# ...

# %%
survey.loc[survey["Country"].isin(SAARC_COUNTRIES),["Country"]]
# Out:
#                Country
# Respondent
# 8                India
# 10               India
# 15               India
# 34           Sri Lanka
# 42          Bangladesh
# ...                ...
# 81624       Bangladesh
# 83862            India
# 84299            India
# 86012            India
# 88182         Pakistan
#
# [11257 rows x 1 columns]

# %% [markdown]
# ######                                         ( or )

# %%
survey.loc[survey["Country"].isin(["Afghanistan","Bangladesh","Bhutan","India","Maldives","Nepal","Pakistan","Sri Lanka"])]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 34          I am a student who is learning to code      Yes
# 42                  I am a developer by profession      Yes
# ...                                            ...      ...
# 81624                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
# 88182                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# ...

# %% [markdown]
# ### 4.Female Developers those earns more than 10L and thier age when they first code

# %%
-gender female
-earns > 10L
-their age when they first code

# %%
schema.loc["Age1stCode","QuestionText"]
# Out:
# 'At what age did you write your first line of code or program? (E.g., webpage, Hello World, Scratch project)'

# %%
survey.loc[((survey["Gender"]=="Woman") & (survey["ConvertedComp"]>1000000)),["Age1stCode"]]
# Out:
#            Age1stCode
# Respondent
# 789                 9
# 1758               16
# 6561               16
# 6939                8
# 9592               16
# ...               ...
# 80200              17
# 84247              17
# 85193              25
# 86327              10
# 86825              20
#
# [68 rows x 1 columns]

# %%
survey.loc[((survey["Gender"]=="Woman") & (survey["ConvertedComp"]>1000000)),["Age1stCode","Gender","ConvertedComp"]]
# Out:
#            Age1stCode Gender  ConvertedComp
# Respondent
# 789                 9  Woman      2000000.0
# 1758               16  Woman      2000000.0
# 6561               16  Woman      2000000.0
# 6939                8  Woman      1152000.0
# 9592               16  Woman      2000000.0
# ...               ...    ...            ...
# 80200              17  Woman      2000000.0
# 84247              17  Woman      1440000.0
# 85193              25  Woman      2000000.0
# 86327              10  Woman      2000000.0
# 86825              20  Woman      2000000.0
#
# [68 rows x 3 columns]

# %% [markdown]
# ### 5.Working Location and Edulevel of developers who gets 20L

# %%
-dev earns = 20L
-their working location
-their edlevel

# %%
schema.loc["WorkLoc","QuestionText"]
# Out:
# 'Where would you prefer to work?'

# %%
survey.loc[(survey["ConvertedComp"] == 2000000),["EdLevel","WorkLoc"]]
# Out:
#                                                 EdLevel WorkLoc
# Respondent
# 58             Bachelor’s degree (BA, BS, B.Eng., etc.)    Home
# 102            Bachelor’s degree (BA, BS, B.Eng., etc.)  Office
# 166            Bachelor’s degree (BA, BS, B.Eng., etc.)    Home
# 436            Bachelor’s degree (BA, BS, B.Eng., etc.)  Office
# 452              I never completed any formal education    Home
# ...                                                 ...     ...
# 88712          Bachelor’s degree (BA, BS, B.Eng., etc.)    Home
# 88815       Master’s degree (MA, MS, M.Eng., MBA, etc.)  Office
# 88818                                  Associate degree  Office
# 88874          Bachelor’s degree (BA, BS, B.Eng., etc.)  Office
# 88877          Bachelor’s degree (BA, BS, B.Eng., etc.)  Office
#
# [709 rows x 2 columns]

# %%
survey.loc[(survey["ConvertedComp"] == 2000000),["EdLevel","WorkLoc","ConvertedComp"]]
# Out:
#                                                 EdLevel WorkLoc  ConvertedComp
# Respondent
# 58             Bachelor’s degree (BA, BS, B.Eng., etc.)    Home      2000000.0
# 102            Bachelor’s degree (BA, BS, B.Eng., etc.)  Office      2000000.0
# 166            Bachelor’s degree (BA, BS, B.Eng., etc.)    Home      2000000.0
# 436            Bachelor’s degree (BA, BS, B.Eng., etc.)  Office      2000000.0
# 452              I never completed any formal education    Home      2000000.0
# ...                                                 ...     ...            ...
# 88712          Bachelor’s degree (BA, BS, B.Eng., etc.)    Home      2000000.0
# 88815       Master’s degree (MA, MS, M.Eng., MBA, etc.)  Office      2000000.0
# 88818                                  Associate degree  Office      2000000.0
# 88874          Bachelor’s degree (BA, BS, B.Eng., etc.)  Office      2000000.0
# 88877          Bachelor’s degree (BA, BS, B.Eng., etc.)  Office      2000000.0
#
# ...
